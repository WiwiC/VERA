# %%
import pandas as pd

# Define the CSV file path
csv_path = "/Users/libiv/code/VERA/data/raw/speechesURLS - Sheet1.csv"  # Replace with our actual .csv file path

# Read the CSV file
df = pd.read_csv(csv_path)

# Extract the specified columns
columns_to_extract = ['Video-name', 'Duration', 'Gender', 'Speaker', 'Accent', 'Our Notes']
df_extracted = df[columns_to_extract]

# Display the extracted table
print(df_extracted.head())
print(f"\nShape: {df_extracted.shape}")
# Out:
#    Video-name Duration Gender  Speaker Accent Our Notes
# 0          23     1:05      F        9    NaN       NaN
# 1           6     1:01      M        2    NaN       NaN
# 2          24     1:00      F       10    NaN       NaN
# 3          21     1:00      M        7    NaN       NaN
# 4          22     0:55      F        8    NaN       NaN
#
# Shape: (57, 6)

# %%
df_extracted
# Out:
#     Video-name Duration Gender  Speaker             Accent  \
# 0           23     1:05      F        9                NaN
# 1            6     1:01      M        2                NaN
# 2           24     1:00      F       10                NaN
# 3           21     1:00      M        7                NaN
# 4           22     0:55      F        8                NaN
# 5           20     0:53      F        6                NaN
# 6           25     0:45      F       11                NaN
# 7           16     0:43      F        4                NaN
# 8           11     0:38      F        3              Asian
# 9           13     0:36      F        4                NaN
# 10           8     0:31      M        2                NaN
# 11          18     0:30      F        5              Asian
# 12          10     0:30      F        3              Asian
# 13          17     0:29      F        5              Asian
# 14          12     0:28      F        3              Asian
# ...
